# %%
import cv2

def img2sketch(path,name):
    image=cv2.imread(path)

    gray_img=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    invert=cv2.bitwise_not(gray_img)

    blur=cv2.GaussianBlur(invert, (21,21),0)

    inverted_blur=cv2.bitwise_not(blur)

    sketch=cv2.divide(gray_img, inverted_blur, scale=256.0)

    cv2.imwrite(f'sketch/{name}.png', sketch)
    
    print("Done")

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input/celebrities-100k/100k/100k'):
    for filename in filenames:
        name = filename.split('.')[0]
#         print(name)
        img2sketch(os.path.join(dirname, filename),name)
# Out:
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# Load the image
img = Image.open('/kaggle/working/sketch/000001.png').convert('L')

# Convert the image to a numpy array for display
img = mpimg.pil_to_array(img)

# Display the image
plt.imshow(img, cmap='gray')  # 'gray' colormap displays in grayscale
plt.axis('off')
plt.show()

print(img.shape)
# Out:
# (128, 128)

# %%
# load all images in a directory into memory
def load_images(path, size=(256,256)):
    src_list, tar_list = list(), list()
    
    src_path = "/kaggle/working/sketch/"
    tar_path = "/kaggle/input/celebrities-100k/100k/100k/"


    # load and resize the image
    src_img = load_img(src_path + filename, target_size=size)

    # convert to an array
    pixels = img_to_array(pixels)

    # split into satellite and map
    sat_img, map_img = pixels[:, :256], pixels[:, 256:]

    src_list.append(sat_img)
    tar_list.append(map_img)

    return [asarray(src_list), asarray(tar_list)]

# %%
a ='ab/bv'
b="g/bh"
print(a+b)
# Out:
# ab/bvg/bh
